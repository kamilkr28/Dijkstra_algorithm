# %%
from Dijkstra_algorithm import Graph, Visualizer

# %%
graf = {
    'A': [('B', 2), ('C', 4), ('D', 8)],
    'B': [('C', 4), ('E', 9)],
    'C': [('D', 1), ('E', 3), ('F', 9)],
    'D': [('G', 12), ('F', 6)],
    'E': [('F', 2), ('H', 3), ('I', 13)],
    'F': [('G', 5), ('I', 9), ('J', 7)],
    'G': [('J', 1)],
    'H': [('I', 8)],
    'I': [],
    'J': [('I', 2)]
}

# %%
pos = {
    'A': (0, 2),
    'B': (1, 3),
    'C': (1, 2),
    'D': (1, 1),
    'E': (2, 3),
    'F': (2, 2),
    'G': (2, 1),
    'H': (3, 3),
    'I': (3, 2),
    'J': (3, 1)
}

# %%
a = Graph(graf)

# %%
a.shortest_path_from('A', 'I', pos)
# Out:
# Najkrótsza ścieżka z A do I: ['A', 'C', 'E', 'F', 'G', 'J', 'I']
# Minimalna waga ścieżki: 17
# (['A', 'C', 'E', 'F', 'G', 'J', 'I'], 17)
