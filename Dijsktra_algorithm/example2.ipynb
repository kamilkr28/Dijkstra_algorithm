# %%
from Dijkstra_algorithm import Graph, Visualizer

# %%
a = Graph(directed=False)
a.add_edge("A","B",30)
a.add_edge("A","C",50)
a.add_edge("B","D",6)
a.add_edge("B","E",40)
a.add_edge("D","C",12)
a.add_edge("C","D",12)
a.add_edge("C","F",10)
a.add_edge("B","C",14)
a.add_edge("D","E",13)
a.add_edge("D","F",23)
a.add_edge("E","F",11)
a.add_edge("E","G",8)
a.add_edge("F","G",20)

pos = {
    'A': (0, 2),
    'B': (1, 3),
    'C': (1, 1),
    'D': (2, 2),
    'E': (3, 3),
    'F': (3, 1),
    'G': (4, 2)
}





a.shortest_path_from("A","G",pos)
# Out:
# Najkrótsza ścieżka z A do G: ['A', 'B', 'D', 'E', 'G']
# Minimalna waga ścieżki: 57
# (['A', 'B', 'D', 'E', 'G'], 57)
